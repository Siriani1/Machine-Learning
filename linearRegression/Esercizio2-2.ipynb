# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
header_list = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
df = pd.read_csv('data/Housing.data', names=header_list, delim_whitespace=True)
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
y = df['MEDV']
x = df[['B']]

# %%
Xnp = x.to_numpy()
Xnp
# Out:
# array([[3.9690e+02],
#        [3.9690e+02],
#        [3.9283e+02],
#        [3.9463e+02],
#        [3.9690e+02],
#        [3.9412e+02],
#        [3.9560e+02],
#        [3.9690e+02],
#        [3.8663e+02],
#        [3.8671e+02],
#        [3.9252e+02],
#        [3.9690e+02],
#        [3.9050e+02],
#        [3.9690e+02],
#        [3.8002e+02],
#        [3.9562e+02],
#        [3.8685e+02],
#        [3.8675e+02],
#        [2.8899e+02],
#        [3.9095e+02],
#        [3.7657e+02],
#        [3.9253e+02],
#        [3.9690e+02],
#        [3.9454e+02],
#        [3.9433e+02],
#        [3.0342e+02],
#        [3.7688e+02],
#        [3.0638e+02],
#        [3.8794e+02],
#        [3.8023e+02],
#        [3.6017e+02],
#        [3.7673e+02],
#        [2.3260e+02],
#        [3.5877e+02],
#        [2.4831e+02],
#        [3.9690e+02],
#        [3.7756e+02],
#        [3.9690e+02],
#        [3.9343e+02],
#        [3.9563e+02],
#        [3.9562e+02],
#        [3.8541e+02],
#        [3.8337e+02],
# ...

# %%
Ynp = y.to_numpy()
Ynp
# Out:
# array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#        18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#        15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#        13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
#        21.2, 19.3, 20. , 16.6, 14.4, 19.4, 19.7, 20.5, 25. , 23.4, 18.9,
#        35.4, 24.7, 31.6, 23.3, 19.6, 18.7, 16. , 22.2, 25. , 33. , 23.5,
#        19.4, 22. , 17.4, 20.9, 24.2, 21.7, 22.8, 23.4, 24.1, 21.4, 20. ,
#        20.8, 21.2, 20.3, 28. , 23.9, 24.8, 22.9, 23.9, 26.6, 22.5, 22.2,
#        23.6, 28.7, 22.6, 22. , 22.9, 25. , 20.6, 28.4, 21.4, 38.7, 43.8,
#        33.2, 27.5, 26.5, 18.6, 19.3, 20.1, 19.5, 19.5, 20.4, 19.8, 19.4,
#        21.7, 22.8, 18.8, 18.7, 18.5, 18.3, 21.2, 19.2, 20.4, 19.3, 22. ,
#        20.3, 20.5, 17.3, 18.8, 21.4, 15.7, 16.2, 18. , 14.3, 19.2, 19.6,
#        23. , 18.4, 15.6, 18.1, 17.4, 17.1, 13.3, 17.8, 14. , 14.4, 13.4,
# ...

# %%
from sklearn.model_selection import train_test_split # suddivide le osservazioni nei due insiemi

X_train, X_test, y_train, y_test = train_test_split(Xnp, Ynp, 
                                                    test_size = 0.33, 
                                                    random_state = 123) # fix random seed for replicability

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((339, 1), (339,), (167, 1), (167,))

# %%
from sklearn.linear_model import LogisticRegression

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-288448b7a3f1> in <module>
# ----> 1 model = LogisticRegression(solver='liblinear', random_state=0).fit(x, y)
#
# ~\anaconda3\envs\geo_env\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
# -> 1516         check_classification_targets(y)
#    1517         self.classes_ = np.unique(y)
#    1518
#
# ~\anaconda3\envs\geo_env\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     195         "multilabel-sequences",
#     196     ]:
# --> 197         raise ValueError("Unknown label type: %r" % y_type)
#     198
#     199
#
# ValueError: Unknown label type: 'continuous'

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-d768f88d541e> in <module>
# ----> 1 model.fit(X_train, y_train)
#
# ~\anaconda3\envs\geo_env\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1514             accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515         )
# -> 1516         check_classification_targets(y)
#    1517         self.classes_ = np.unique(y)
#    1518
#
# ~\anaconda3\envs\geo_env\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     195         "multilabel-sequences",
#     196     ]:
# --> 197         raise ValueError("Unknown label type: %r" % y_type)
#     198
#     199
#
# ValueError: Unknown label type: 'continuous'
